# %%
# !nvidia-smi
# Out:
# Wed Oct 30 18:35:41 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
# !pip install pandas==2.2.2 scipy==1.13.1 scikit-learn==1.5.2 supervision==0.24.0 ultralytics==8.3.7 roboflow==1.1.47 opencv-python==4.10.0.84
# Out:
# Requirement already satisfied: pandas==2.2.2 in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: scipy==1.13.1 in /usr/local/lib/python3.10/dist-packages (1.13.1)
# Requirement already satisfied: scikit-learn==1.5.2 in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Collecting supervision==0.24.0
#   Downloading supervision-0.24.0-py3-none-any.whl.metadata (14 kB)
# Collecting ultralytics==8.3.7
#   Downloading ultralytics-8.3.7-py3-none-any.whl.metadata (34 kB)
# Collecting roboflow==1.1.47
#   Downloading roboflow-1.1.47-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: opencv-python==4.10.0.84 in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas==2.2.2) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas==2.2.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.2.2) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas==2.2.2) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.5.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.5.2) (3.5.0)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from supervision==0.24.0) (0.7.1)
# Requirement already satisfied: matplotlib>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from supervision==0.24.0) (3.7.1)
# Requirement already satisfied: pillow>=9.4 in /usr/local/lib/python3.10/dist-packages (from supervision==0.24.0) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.10/dist-packages (from supervision==0.24.0) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.7) (2.32.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.7) (2.5.0+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.7) (0.20.0+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.7) (4.66.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.7) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.7) (9.0.0)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.7) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics==8.3.7)
#   Downloading ultralytics_thop-2.0.10-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from roboflow==1.1.47) (2024.8.30)
# Collecting idna==3.7 (from roboflow==1.1.47)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /usr/local/lib/python3.10/dist-packages (from roboflow==1.1.47) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow==1.1.47) (1.4.7)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.10/dist-packages (from roboflow==1.1.47) (4.10.0.84)
# Collecting python-dotenv (from roboflow==1.1.47)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow==1.1.47) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow==1.1.47) (2.2.3)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.10/dist-packages (from roboflow==1.1.47) (1.0.0)
# Collecting filetype (from roboflow==1.1.47)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->supervision==0.24.0) (1.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->supervision==0.24.0) (4.54.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->supervision==0.24.0) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->supervision==0.24.0) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics==8.3.7) (3.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.7) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.7) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.7) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.7) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.7) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.7) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics==8.3.7) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics==8.3.7) (3.0.2)
# Downloading supervision-0.24.0-py3-none-any.whl (158 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 kB 10.4 MB/s eta 0:00:00
# Downloading ultralytics-8.3.7-py3-none-any.whl (882 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.0/883.0 kB 33.6 MB/s eta 0:00:00
# Downloading roboflow-1.1.47-py3-none-any.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.4/80.4 kB 7.3 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.6 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.10-py3-none-any.whl (26 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: filetype, python-dotenv, idna, ultralytics-thop, supervision, ultralytics, roboflow
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# Successfully installed filetype-1.2.0 idna-3.7 python-dotenv-1.0.1 roboflow-1.1.47 supervision-0.24.0 ultralytics-8.3.7 ultralytics-thop-2.0.10

# %%
# !pwd
# Out:
# /content

# %%
from google.colab import userdata
import roboflow

# Retrieve the Roboflow API key from Colab's secret management
roboflow_key = userdata.get('roboflow_key')  # Replace 'roboflow_key' with your actual secret name

# Check if the key is retrieved successfully
if roboflow_key is None:
    raise RuntimeError("API Key not found. Please check your Colab Secrets.")

# Initialize Roboflow
rf = roboflow.Roboflow(api_key=roboflow_key)

# Access the workspace and project
project = rf.workspace("mihailo").project("football-field-detection-f07vi-apxzb")

# Access the specific version of the dataset
version = project.version(1)

# Download the dataset in YOLOv8 format
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Dependency ultralytics==8.0.196 is required but found version=8.3.7, to fix: `pip install ultralytics==8.0.196`
# Downloading Dataset Version Zip in football-field-detection-1 to yolov8:: 100%|██████████| 227749/227749 [00:05<00:00, 45313.40it/s]
# Extracting Dataset Version Zip to football-field-detection-1 in yolov8:: 100%|██████████| 1666/1666 [00:00<00:00, 2141.95it/s]

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# football-field-detection-1  sample_data

# %%
# !ls football-field-detection-1
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
import os
''' import cv2
import matplotlib.pyplot as plt

# Function to convert YOLO format to bounding box coordinates
def yolo_to_bbox(image_width, image_height, x_center, y_center, width, height):
    # Convert YOLO center coordinates and dimensions to pixel values
    x_center *= image_width
    y_center *= image_height
    width *= image_width
    height *= image_height

    # Calculate the top-left and bottom-right coordinates
    x1 = int(x_center - width / 2)
    y1 = int(y_center - height / 2)
    x2 = int(x_center + width / 2)
    y2 = int(y_center + height / 2)

    return x1, y1, x2, y2

# Path to the images and labels
image_dir = 'football-players-detection-2/train/images/'
label_dir = 'football-players-detection-2/train/labels/'

# List of image files
image_files = os.listdir(image_dir)

# Load class names from the data.yaml file (make sure to have already loaded this)
# Assuming class_names has been defined earlier from data.yaml
class_names = ['ball', 'goalkeeper', 'player', 'referee']  # Example, modify according to your class names

# Display a few images with their annotations and class names
for img_file in image_files[:5]:  # Display first 5 images
    img_path = os.path.join(image_dir, img_file)
    img = cv2.imread(img_path)
    img_height, img_width, _ = img.shape
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert to RGB for Matplotlib

    # Load and display the corresponding label
    label_file = img_file.replace('.jpg', '.txt')  # Assuming labels are in .txt format
    label_path = os.path.join(label_dir, label_file)

    # Read the label file
    with open(label_path, 'r') as file:
        for line in file:
            parts = line.strip().split()
            class_id = int(parts[0])
            x_center = float(parts[1])
            y_center = float(parts[2])
            width = float(parts[3])
            height = float(parts[4])

            # Convert YOLO format to bounding box coordinates
            x1, y1, x2, y2 = yolo_to_bbox(img_width, img_height, x_center, y_center, width, height)

            # Draw the bounding box
            cv2.rectangle(img, (x1, y1), (x2, y2), color=(255, 0, 0), thickness=2)

            # Annotate with class name
            class_name = class_names[class_id]
            cv2.putText(img, class_name, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

    # Display image
    plt.imshow(img)
    plt.axis('off')
    plt.title(f'Image: {img_file}')
    plt.show() '''
# Out:
# " import cv2\nimport matplotlib.pyplot as plt\n\n# Function to convert YOLO format to bounding box coordinates\ndef yolo_to_bbox(image_width, image_height, x_center, y_center, width, height):\n    # Convert YOLO center coordinates and dimensions to pixel values\n    x_center *= image_width\n    y_center *= image_height\n    width *= image_width\n    height *= image_height\n\n    # Calculate the top-left and bottom-right coordinates\n    x1 = int(x_center - width / 2)\n    y1 = int(y_center - height / 2)\n    x2 = int(x_center + width / 2)\n    y2 = int(y_center + height / 2)\n\n    return x1, y1, x2, y2\n\n# Path to the images and labels\nimage_dir = 'football-players-detection-2/train/images/'\nlabel_dir = 'football-players-detection-2/train/labels/'\n\n# List of image files\nimage_files = os.listdir(image_dir)\n\n# Load class names from the data.yaml file (make sure to have already loaded this)\n# Assuming class_names has been defined earlier from data.yaml\nclass_names = ['ball', 'goalkeeper', 'player', 'referee']  # Example, modify according to your class names\n\n# Display a few images with their annotations and class names\nfor img_file in image_files[:5]:  # Display first 5 images\n    img_path = os.path.join(image_dir, img_file)\n    img = cv2.imread(img_path)\n    img_height, img_width, _ = img.shape\n    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert to RGB for Matplotlib\n\n    # Load and display the corresponding label\n    label_file = img_file.replace('.jpg', '.txt')  # Assuming labels are in .txt format\n    label_path = os.path.join(label_dir, label_file)\n\n    # Read the label file\n    with open(label_path, 'r') as file:\n        for line in file:\n            parts = line.strip().split()\n            class_id = int(parts[0])\n            x_center = float(parts[1])\n            y_center = float(parts[2])\n            width = float(parts[3])\n            height = float(parts[4])\n\n            # Convert YOLO format to bounding box coordinates\n            x1, y1, x2, y2 = yolo_to_bbox(img_width, img_height, x_center, y_center, width, height)\n\n            # Draw the bounding box\n            cv2.rectangle(img, (x1, y1), (x2, y2), color=(255, 0, 0), thickness=2)\n\n            # Annotate with class name\n            class_name = class_names[class_id]\n            cv2.putText(img, class_name, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)\n\n    # Display image\n    plt.imshow(img)\n    plt.axis('off')\n    plt.title(f'Image: {img_file}')\n    plt.show() "

# %%
# Set the YAML_PATH to the location of your data.yaml file
YAML_PATH = '/content/datasets/data.yaml'

# %%
# Move the dataset to the expected location
# !mv football-field-detection-1 /content/datasets/

# %%
# !ls -l /content/datasets
# Out:
# total 24
# -rw-r--r-- 1 root root  519 Oct 30 18:36 data.yaml
# -rw-r--r-- 1 root root  171 Oct 30 18:36 README.dataset.txt
# -rw-r--r-- 1 root root 1163 Oct 30 18:36 README.roboflow.txt
# drwxr-xr-x 4 root root 4096 Oct 30 18:36 test
# drwxr-xr-x 4 root root 4096 Oct 30 18:36 train
# drwxr-xr-x 4 root root 4096 Oct 30 18:36 valid

# %%
import os

# List files and directories in '/content/datasets'
dataset_dir = '/content/datasets/'
print("Contents of /content/datasets/:")
print(os.listdir(dataset_dir))
# Out:
# Contents of /content/datasets/:
# ['train', 'README.roboflow.txt', 'valid', 'test', 'README.dataset.txt', 'data.yaml']

# %%
# Training command for YOLO
# !yolo task=pose mode=train model=yolo11n-pose.pt data={YAML_PATH} batch=32 epochs=500 patience=40 imgsz=640 mosaic=0.0 plots=True cache=False
# Out:
# New https://pypi.org/project/ultralytics/8.3.25 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.7 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# engine/trainer: task=pose, mode=train, model=yolo11n-pose.pt, data=/content/datasets/data.yaml, epochs=500, time=None, patience=40, batch=32, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train3, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=0.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/pose/train3
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 24.6MB/s]
# Overriding model.yaml kpt_shape=[17, 3] with kpt_shape=[32, 3]
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1   1095859  ultralytics.nn.modules.head.Pose             [1, [32, 3], [64, 128, 256]]
# YOLO11n-pose summary: 344 layers, 3,255,027 parameters, 3,255,011 gradients, 9.2 GFLOPs
#
# Transferred 505/541 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/pose/train3', view at http://localhost:6006/
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 3
# wandb: You chose "Don't visualize my results"
# wandb: Tracking run with wandb version 0.18.5
# wandb: W&B syncing is set to `offline` in this directory.
# wandb: Run `wandb online` or set WANDB_MODE=online to enable cloud syncing.
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLO11n...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100% 5.35M/5.35M [00:00<00:00, 101MB/s]
# AMP: checks passed ✅
# train: Scanning /content/datasets/train/labels... 765 images, 0 backgrounds, 0 corrupt: 100% 765/765 [00:00<00:00, 1131.27it/s]
# train: New cache created: /content/datasets/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/datasets/valid/labels... 34 images, 0 backgrounds, 0 corrupt: 100% 34/34 [00:00<00:00, 516.23it/s]
# val: New cache created: /content/datasets/valid/labels.cache
# Plotting labels to runs/pose/train3/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 87 weight(decay=0.0), 97 weight(decay=0.0005), 96 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/pose/train3
# Starting training for 500 epochs...
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       1/500      5.35G       1.74      11.62     0.6828      2.321      2.363         29        640: 100% 24/24 [00:21<00:00,  1.10it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.24it/s]
#                    all         34         34      0.941          1      0.991      0.685          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       2/500      5.01G     0.4524      10.54     0.4829     0.3271      1.224         29        640: 100% 24/24 [00:17<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.08it/s]
#                    all         34         34       0.78          1      0.991      0.749          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       3/500      5.02G     0.4425      9.485     0.3304     0.3345      1.185         29        640: 100% 24/24 [00:16<00:00,  1.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.04it/s]
#                    all         34         34      0.983          1      0.995      0.948          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       4/500      5.02G     0.3868      8.766     0.2968      0.296      1.139         29        640: 100% 24/24 [00:16<00:00,  1.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.85it/s]
#                    all         34         34      0.918      0.995      0.988      0.842          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       5/500      5.02G     0.4181      7.801     0.2677     0.3241      1.165         29        640: 100% 24/24 [00:16<00:00,  1.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.71it/s]
#                    all         34         34      0.908      0.824       0.95      0.753          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       6/500      5.02G     0.4047      6.558     0.2636     0.3074      1.154         29        640: 100% 24/24 [00:17<00:00,  1.39it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.65it/s]
#                    all         34         34       0.07     0.0588     0.0338    0.00967          0          0          0          0
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       7/500      5.02G     0.3613      6.766     0.2612     0.2927      1.109         29        640: 100% 24/24 [00:16<00:00,  1.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.89it/s]
#                    all         34         34       0.98      0.941      0.994      0.863     0.0224     0.0294    0.00538   0.000781
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       8/500      5.02G     0.3868      5.814     0.2467     0.2828      1.141         29        640: 100% 24/24 [00:16<00:00,  1.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.66it/s]
#                    all         34         34      0.853          1      0.994      0.802    0.00277     0.0294    0.00146   0.000291
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       9/500      5.02G     0.3437      5.027     0.2431     0.2763      1.098         29        640: 100% 24/24 [00:16<00:00,  1.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.95it/s]
#                    all         34         34      0.977      0.941      0.992      0.883     0.0611     0.0588     0.0235    0.00731
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      10/500      5.02G     0.3509      4.836     0.2249     0.2703      1.091         29        640: 100% 24/24 [00:16<00:00,  1.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.09it/s]
#                    all         34         34          1      0.999      0.995      0.969      0.284      0.294      0.161      0.027
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      11/500      5.02G     0.2962      3.808     0.2104      0.242      1.051         29        640: 100% 24/24 [00:17<00:00,  1.35it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.08it/s]
#                    all         34         34       0.96      0.882      0.968      0.855      0.453      0.585      0.408      0.106
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      12/500      5.02G     0.3216      4.292     0.2085      0.251      1.056         29        640: 100% 24/24 [00:17<00:00,  1.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.06s/it]
#                    all         34         34      0.972          1      0.995      0.907      0.576      0.588      0.542       0.15
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      13/500      5.02G     0.2842      3.489     0.2016     0.2265      1.038         29        640: 100% 24/24 [00:15<00:00,  1.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.01it/s]
#                    all         34         34      0.996          1      0.995      0.919      0.761      0.765      0.683      0.207
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      14/500      5.02G      0.291      3.408     0.1987     0.2258      1.034         29        640: 100% 24/24 [00:17<00:00,  1.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.76it/s]
#                    all         34         34      0.999          1      0.995      0.951      0.763      0.765      0.647      0.215
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      15/500      5.02G     0.2773      3.149      0.194     0.2207      1.018         29        640: 100% 24/24 [00:16<00:00,  1.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.82it/s]
#                    all         34         34      0.999          1      0.995      0.959      0.881      0.882      0.853      0.354
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      16/500      5.02G     0.2551       3.18     0.1884     0.2114      1.004         29        640: 100% 24/24 [00:16<00:00,  1.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.97it/s]
#                    all         34         34      0.998          1      0.995      0.935      0.558      0.559      0.405       0.14
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      17/500      5.02G     0.2498      3.066     0.1898     0.2119      1.005         29        640: 100% 24/24 [00:16<00:00,  1.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.87it/s]
#                    all
00:00,  1.39it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.71it/s]
#                    all         34         34          1          1      0.995      0.995          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     496/500      5.02G    0.05086     0.1019    0.04862    0.05027     0.8577         29        640: 100% 24/24 [00:16<00:00,  1.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.63it/s]
#                    all         34         34          1          1      0.995      0.995          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     497/500      5.02G    0.05161     0.1061    0.05052    0.04972     0.8628         29        640: 100% 24/24 [00:17<00:00,  1.39it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.27it/s]
#                    all         34         34          1          1      0.995      0.995          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     498/500      5.02G    0.05195    0.09699    0.04958    0.05137     0.8589         29        640: 100% 24/24 [00:16<00:00,  1.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.10it/s]
#                    all         34         34          1          1      0.995      0.995          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     499/500      5.02G    0.05065     0.1031    0.05018    0.05025      0.872         29        640: 100% 24/24 [00:16<00:00,  1.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.32it/s]
#                    all         34         34          1          1      0.995      0.995          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     500/500      5.02G    0.04963     0.1024    0.04638    0.05098     0.8654         29        640: 100% 24/24 [00:17<00:00,  1.35it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.05it/s]
#                    all         34         34          1          1      0.995      0.995          1          1      0.995      0.995
#
# 500 epochs completed in 2.757 hours.
# Optimizer stripped from runs/pose/train3/weights/last.pt, 6.9MB
# Optimizer stripped from runs/pose/train3/weights/best.pt, 6.9MB
#
# Validating runs/pose/train3/weights/best.pt...
# Ultralytics 8.3.7 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n-pose summary (fused): 257 layers, 3,246,763 parameters, 0 gradients, 9.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.31it/s]
#                    all         34         34          1          1      0.995      0.995          1          1      0.995      0.995
# Speed: 0.2ms preprocess, 2.9ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to runs/pose/train3
# wandb:
# wandb:
# wandb: Run history:
# wandb:                  lr/pg0 ▃█████▇▇▇▆▆▆▅▅▅▅▅▅▄▄▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▁▁▁▁▁
# wandb:                  lr/pg1 ████▇▇▇▇▇▇▇▇▇▇▇▆▆▆▆▅▅▅▅▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▁▁
# wandb:                  lr/pg2 ██████▇▇▇▇▇▇▇▇▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▂▂▂▂▁▁▁▁▁▁
# wandb:        metrics/mAP50(B) ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:        metrics/mAP50(P) ▁▁▁▆████████████████████████████████████
# wandb:     metrics/mAP50-95(B) ▁▆▇█████████████████████████████████████
# wandb:     metrics/mAP50-95(P) ▁▁▂▆▇▇▇▇▇▂▇█████████████████████████████
# wandb:    metrics/precision(B) ▃▃▃▁▃▃█▃▃▃█▂▃▃▃▃▃▃▃▃▃█▃███▃█▃▃██████████
# wandb:    metrics/precision(P) ▁███████████████████████████████████████
# wandb:       metrics/recall(B) █▅▁█████████████████████████████████████
# wandb:       metrics/recall(P) ▁▁▁▅████████████████████████████████████
# wandb:            model/GFLOPs ▁
# wandb:        model/parameters ▁
# wandb: model/speed_PyTorch(ms) ▁
# wandb:          train/box_loss █▅▅▅▄▅▄▄▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁
# wandb:          train/cls_loss █▇▆▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁
# wandb:          train/dfl_loss █▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:         train/kobj_loss █▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:         train/pose_loss █▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:            val/box_loss ███▅▅▅▄▄▄▃▃▃▄▃▃▃▃▃▂▂▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁
# wandb:            val/cls_loss █▃▃▂▃▂▂▂▂▂▁▂▃▂▂▄▂▃▂▁▁▂▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:            val/dfl_loss ██▇▆▅▄▅▄▄▃▄▄▄▄▄▃▃▄▂▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁
# wandb:           val/kobj_loss █▆▅▅▅▄▄▄▄▄▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:           val/pose_loss ▄▃▂▂▂▁▂▂▁▁▁█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:                  lr/pg0 2e-05
# wandb:                  lr/pg1 2e-05
# wandb:                  lr/pg2 2e-05
# wandb:        metrics/mAP50(B) 0.995
# wandb:        metrics/mAP50(P) 0.995
# wandb:     metrics/mAP50-95(B) 0.995
# wandb:     metrics/mAP50-95(P) 0.995
# wandb:    metrics/precision(B) 1
# wandb:    metrics/precision(P) 1
# wandb:       metrics/recall(B) 1
# wandb:       metrics/recall(P) 1
# wandb:            model/GFLOPs 9.24
# wandb:        model/parameters 3255027
# wandb: model/speed_PyTorch(ms) 11.227
# wandb:          train/box_loss 0.04963
# wandb:          train/cls_loss 0.05098
# wandb:          train/dfl_loss 0.86535
# wandb:         train/kobj_loss 0.04638
# wandb:         train/pose_loss 0.10239
# wandb:            val/box_loss 0.1093
# wandb:            val/cls_loss 0.10609
# wandb:            val/dfl_loss 0.35918
# wandb:           val/kobj_loss 0.05033
# wandb:           val/pose_loss 0.05869
# wandb:
# wandb: You can sync this run to the cloud by running:
# wandb: wandb sync /content/wandb/offline-run-20241030_184239-isbvip4y
# wandb: Find logs at: ./wandb/offline-run-20241030_184239-isbvip4y/logs
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
from google.colab import files
files.download('/content/runs/pose/train3/weights/best.pt')
